# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import math
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import math

# %%
NSAMPLE = 1000
x_data = np.float32(np.random.uniform(-10.5, 10.5, (1, NSAMPLE))).T
r_data = np.float32(np.random.normal(size=(NSAMPLE,1)))
y_data = np.float32(np.sin(0.75*x_data)*7.0+x_data*0.5+r_data*1.0)

plt.figure(figsize=(8, 8))
plot_out = plt.plot(x_data,y_data,'ro',alpha=0.3)
plt.show()

# %%
y_data.shape
# Out:
# (1000, 1)

# %%
# create model
model = Sequential()
model.add(Dense(20, input_dim=1000, activation='tanh'))

# %%
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model.fit(x_data, y_data, epochs=5, batch_size=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-174-3bccad6ae092> in <module>()
#       1 # Fit the model
# ----> 2 model.fit(x_data, y_data, epochs=5, batch_size=10)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     963                               initial_epoch=initial_epoch,
#     964                               steps_per_epoch=steps_per_epoch,
# --> 965                               validation_steps=validation_steps)
#     966
#     967     def evaluate(self, x=None, y=None,
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1591             class_weight=class_weight,
#    1592             check_batch_axis=False,
# -> 1593             batch_size=batch_size)
#    1594         # Prepare validation data.
#    1595         do_validation = False
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1424                                     self._feed_input_shapes,
#    1425                                     check_batch_axis=False,
# -> 1426                                     exception_prefix='input')
#    1427         y = _standardize_input_data(y, self._feed_output_names,
#    1428                                     output_shapes,
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     118                             ': expected ' + names[i] + ' to have shape ' +
#     119                             str(shape) + ' but got array with shape ' +
# --> 120                             str(data_shape))
#     121     return data
#     122
#
# ValueError: Error when checking input: expected dense_20_input to have shape (1000,) but got array with shape (1,)

# %%
x_test = np.float32(np.random.uniform(-10.5, 10.5, (1, NSAMPLE))).T

# %%
xx_test = x_test.reshape(-1,20)

# %%
y_hat = model.predict(xx_test)

# %%
y_hat.max()
# Out:
# 1.0000001

# %%
plt.plot(xx_test.reshape,y_hat.ravel(),'ro')
plt.show()

# %%
yy.shape
# Out:
# (1000, 1)

# %%
x_test.shape
# Out:
# (1000, 1)

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x_data,y_data,'ro',alpha=0.3)
ax.plot(x_test,yy,'bo',alpha=0.3)
plt.show()

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# %%
x = tf.placeholder(dtype=tf.float32, shape=[None,1])
y = tf.placeholder(dtype=tf.float32, shape=[None,1])

NHIDDEN = 20
W = tf.Variable(tf.random_normal([1,NHIDDEN], stddev=1.0, dtype=tf.float32))
b = tf.Variable(tf.random_normal([1,NHIDDEN], stddev=1.0, dtype=tf.float32))

W_out = tf.Variable(tf.random_normal([NHIDDEN,1], stddev=1.0, dtype=tf.float32))
b_out = tf.Variable(tf.random_normal([1,1], stddev=1.0, dtype=tf.float32))

hidden_layer = tf.nn.tanh(tf.matmul(x, W) + b)
y_out = tf.matmul(hidden_layer,W_out) + b_out

# %%
lossfunc = tf.nn.l2_loss(y_out-y)
train_op = tf.train.RMSPropOptimizer(learning_rate=0.1, decay=0.8).minimize(lossfunc)

sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

# %%
NSAMPLE = 1000
x_data = np.float32(np.random.uniform(-10.5, 10.5, (1, NSAMPLE))).T
r_data = np.float32(np.random.normal(size=(NSAMPLE,1)))
y_data = np.float32(np.sin(0.75*x_data)*7.0+x_data*0.5+r_data*1.0)
NEPOCH = 100
for i in range(NEPOCH):
    sess.run(train_op, feed_dict={x: x_data, y: y_data})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-161-9755a2322847> in <module>()
#       5 NEPOCH = 100
#       6 for i in range(NEPOCH):
# ----> 7     sess.run(train_op, feed_dict={x: x_data, y: y_data})
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
#         -9.72810555e+00,   2.27090573e+00,   6.75387335e+00,
#         -5.68711853e+00,   1.83957708e+00,   1.36421442e+00,
#          6.50860405e+00,  -1.35596707e-01,   1.05557406e+00,
#         -6.58446550e+00,  -3.40664499e-02,   1.86164689e+00,
#          8.74749660e-01,  -6.03982401e+00,   9.02254677e+00,
#          1.67096043e+00,   5.19990158e+00,  -5.91572571e+00,
#         -6.48211670e+00,  -9.97580433e+00,  -9.95075926e-02,
#         -5.07155561e+00,   8.08078766e+00,  -3.40130520e+00,
#          9.49310303e+00,   9.51990604e+00,  -7.16553974e+00,
#         -5.39909410e+00,   3.17849708e+00,  -2.60623991e-01,
#         -4.69201899e+00,   6.53276873e+00,  -7.55714083e+00,
#         -4.69305277e+00,  -7.70601368e+00,   6.67983007e+00,
#         -7.16639137e+00,  -9.54868984e+00,   1.46547973e+00,
#          6.98936462e+00,   5.88735533e+00,  -5.15191936e+00,
#          9.01861668e+00,   1.15505791e+00,   6.78666592e+00,
#          4.85854053e+00,   1.04400511e+01,   3.21928859e+00,
#         -3.04718208e+00,   5.70427835e-01,   5.18577909e+00,
#          2.44754362e+00,  -1.96633542e+00,  -2.00792074e+00,
#         -7.35075235e+00,   5.36667156e+00,   9.78472328e+00,
#          6.64820051e+00,   5.19873524e+00,  -1.41374969e+00,
#         -5.48781776e+00,   1.18991470e+00,   4.22999239e+00,
#          6.36736631e+00,   6.15750837e+00,  -8.12960529e+00,
#         -3.00417018e+00,   1.27386343e+00,   3.68855286e+00,
#          5.56131268e+00,   4.82810402e+00,  -3.76766849e+00,
#          8.76647377e+00,  -8.36312866e+00,   1.02369776e+01,
#         -1.88084400e+00,   1.97472072e+00,   6.43180275e+00,
#         -7.25690269e+00,   8.87778378e+00,  -4.63800907e+00,
#          1.78802267e-01,  -4.05501890e+00,   2.15877962e+00,
#         -5.91316879e-01,   1.12401116e+00,   5.98669100e+00,
#          4.13757451e-02,  -4.70688200e+00,   1.69450057e+00,
#         -8.49173546e+00,  -6.99210739e+00,   8.26327860e-01,
#         -4.21529198e+00,  -8.71703529e+00,  -4.54270697e+00,
#         -1.02415590e+01,  -6.87495136e+00,  -7.90241241e+00,
#         -4.16945362e+00,  -6.94608402e+00,  -8.17480373e+00,
#         -9.52294540e+00,  -5.74025154e+00,   2.06244469e+00,
#          1.02564859e+01,   8.43347263e+00,   5.85343742e+00,
#         -4.12413454e+00,   7.71819448e+00,  -8.42417526e+00,
#         -9.87217808e+00,  -9.65964699e+00,  -6.98780918e+00,
#          7.93434811e+00,  -5.03274977e-01,  -7.37408876e+00,
#          4.33391142e+00,   4.33512354e+00,  -9.43293035e-01,
#         -4.74946308e+00,  -8.33071899e+00,   2.27144384e+00,
#         -9.36853218e+00,  -7.51777363e+00,   4.64385557e+00,
#         -2.94671130e+00,   3.19785547e+00,  -8.21231270e+00,
#         -4.87242699e+00,  -6.82921171e+00,   9.24709606e+00,
#          9.94693279e+00,  -3.79209828e+00,  -9.83813000e+00,
#         -9.71100807e+00], dtype=float32)

# %%
temp_data = x_data
x_data = y_data
y_data = temp_data

plt.figure(figsize=(8, 8))
plot_out = plt.plot(x_data,y_data,'ro',alpha=0.3)
plt.show()
